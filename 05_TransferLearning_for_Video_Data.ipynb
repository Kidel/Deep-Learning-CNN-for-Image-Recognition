# %% [markdown]
# # Transfer Learning for Video Data
# by Gaetano Bonofiglio, Veronica Iovinella
#
# ## Introduction
# We previously used **Transfer Learning** from **Inception Model** to build a classifier for CIFAR-10, which is actually a common dataset for image recognition (despite the very low resolution), with many of different examples for the 10 classes. The dataset allows to reach 80% accuracy with a simple CNN and 90% using Transfer Learning with proper feature extraction using Inception Model. Transfer Learning also proved to be way faster than a CNN made from scratch, completing the training in less than 10 minutes instead of 12 hours.
#
# In this notebook we will study how the technique performs on a custom dataset built around strenghts and weaknesses of the Inception Model, that is built around ImageNet. The dataset is called **apple-drive-duck** and we obtained it by sampling videos we made, containing pictures of apples, hard drives and rubber ducks. Those objects were chosen according to ImageNet strengths and weaknesses. ImageNet has a lot of pictures of apples (24 categories with thousands of images each), very few hard drive images (68 total) and zero rubber ducks (maybe there are collateral rubber ducks in some bathroom or toy images, but ImageNet has no rubber duck class, so the actual number is zero or close to zero, rubber ducks are classified as "baloon" by Inception Model V3). This should give a good variety to study how Transfer Learning behaves with new classes and old classes, also with few examples.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import tensorflow as tf
import prettytensor as pt
import numpy as np
import os

from util import Util
u = Util()
from util_transfer import UtilTransfer
ut = UtilTransfer()

import inception

tf.__version__
# Out:
# '0.9.0'

# %%
import custom_dataset as add
from custom_dataset import num_classes

# %% [markdown]
# ## Load data

# %%
add.dataset_name = "apple-drive-duck"
add.data_dir = "data/" + add.dataset_name + "/"
add.data_url = "https://github.com/Kidel/Deep-Learning-CNN-for-Image-Recognition/raw/master/customData/apple-drive-duck.tar.gz"
# Directory used for the cache files
data_dir = "cache/" + add.dataset_name +"/"

# %% [markdown]
# The dataset will be downloaded automatically if not downloaded already. It's about 19 MB.

# %%
add.maybe_download_and_extract()
# Out:
# Data has apparently already been downloaded and unpacked.

# %% [markdown]
# Now we have to load the dataset. The loader scans the directories and sub-directories for all jpg files and puts them into two lists for the training-set and test-set. This does not actually cache the images, which will be done when the transfer-values are being calculated further below.
#
# The lists of filenames are saved so we can be sure that they are ordered in the same way when reloading the dataset later. This is important so we keep the link between the images and their corresponding Transfer-Values.

# %%
dataset = add.load()
# Out:
# Creating dataset from the files in: data/apple-drive-duck/
# - Data loaded from cache-file: data/apple-drive-duck/apple-drive-duck.pkl

# %% [markdown]
# From *dataset* we can obtain class names and also the paths for the images of the training set and the test set.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['duck', 'drive', 'apple']

# %%
image_paths_train, cls_train, labels_train = dataset.get_training_set()
# This line prints the first image-path to see if it's ok
image_paths_train[0]
# Out:
# '/home/jovyan/work/Deep-Learning-CNN-for-Image-Recognition/data/apple-drive-duck/duck/duck3-0041.jpg'

# %%
image_paths_test, cls_test, labels_test = dataset.get_test_set()
# This line prints the first image-path to see if it's ok
image_paths_test[0]
# Out:
# '/home/jovyan/work/Deep-Learning-CNN-for-Image-Recognition/data/apple-drive-duck/duck/test/duck_test-0138.jpg'

# %% [markdown]
# Some statistics on the dataset

# %%
print("Size of:")
print("- Training-set:\t\t{}".format(len(image_paths_train)))
print("- Test-set:\t\t{}".format(len(image_paths_test)))
# Out:
# Size of:
# - Training-set:		1430
# - Test-set:		442

# %% [markdown]
# ### Helper-function for plotting images

# %%
def plot_images(images, cls_true, cls_pred=None, smooth=True): 
    u.plot_images_2(images=images, cls_true=cls_true, class_names=class_names, cls_pred=cls_pred, smooth=smooth)

# %% [markdown]
# Some plots to see if everything is ok

# %%
from matplotlib.image import imread

def load_images(image_paths):
    # Load the images from disk.
    images = [imread(path) for path in image_paths]
    # Convert to a numpy array and return it.
    return np.asarray(images)

# Load the first images from the test-set.
images = load_images(image_paths=(image_paths_train[3:7]+image_paths_train[555:557]+image_paths_train[-4:-1]))

# Get the true classes for those images.
cls_true = np.append(np.append(cls_train[3:7], cls_train[555:557]), cls_train[-4:-1])

# Plot the images and labels using our helper-function above.
plot_images(images=images, cls_true=cls_true, smooth=True)

# %%
images = load_images(image_paths=image_paths_train)
images_test = load_images(image_paths=image_paths_test)

# %% [markdown]
# ### Download and Load the Inception Model

# %%
# inception.data_dir = 'inception/'
inception.maybe_download()

model = inception.Inception()
# Out:
# ...
# Data has apparently already been downloaded and unpacked.

# %% [markdown]
# Here we set the paths where Inception model will save the Transfer-Values in cache files.

# %%
from inception import transfer_values_cache

cache_dir = "cache/"
file_path_cache_test = os.path.join(cache_dir, 'inception_05_test.pkl')
file_path_cache_train = os.path.join(cache_dir, 'inception_05_train.pkl')

# %% [markdown]
# This time we don't need to scale how pixel values are coded, since we already have jpegs. We can calculate the Transfer-Values right away.

# %%
transfer_values_test = transfer_values_cache(cache_path=file_path_cache_test,
                                             image_paths=image_paths_test,
                                             model=model)

transfer_values_train = transfer_values_cache(cache_path=file_path_cache_train,
                                              image_paths=image_paths_train,
                                              model=model)
# Out:
# - Data loaded from cache-file: cache/inception_05_test.pkl
# - Data loaded from cache-file: cache/inception_05_train.pkl

# %% [markdown]
# We can check the shapes of the Transfer-Value arrays.

# %%
transfer_values_train.shape
# Out:
# (1430, 2048)

# %%
transfer_values_test.shape
# Out:
# (442, 2048)

# %% [markdown]
# ### Helper-function for plotting Transfer-Values

# %%
def plot_transfer_values(i): 
    u.plot_transfer_values(i=i, images=images, transfer_values=transfer_values_test)

# %%
plot_transfer_values(6)
# Out:
# Input image:
# Transfer-values for the image using Inception model:

# %% [markdown]
# ## Analysis of Transfer-Values
# As we did in the last notebook, we want to check if the Transfer-Values retain enough information to discriminate between the different classes.
# To do so, we are going to use the same two clustering algorithms we used before: PCA and t-SNE.

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

transfer_values = transfer_values_train
cls = cls_train

# First we reduce the dimensions from 2048 to 50 using PCA
pca = PCA(n_components=50)
transfer_values_50d = pca.fit_transform(transfer_values)

# Then we reduce to 2 dimensions using t-SNE
tsne = TSNE(n_components=2)
transfer_values_reduced = tsne.fit_transform(transfer_values_50d)

# Helper function to plot the scatter
def plot_scatter(values, cls): 
    u.plot_scatter(values=values, cls=cls, num_classes=num_classes)

# %%
plot_scatter(transfer_values_reduced, cls)

# %% [markdown]
# ## Classification of Transfer-Values
# We will now code a new classifier using  $TensorFlow$ and **PrettyTensor** as in the previous notebook.
# The new network will take the transfer values as input (x) and then output the classes from our custom dataset.
#
# ### Placeholder Variables

# %%
transfer_len = model.transfer_len
x = tf.placeholder(tf.float32, shape=[None, transfer_len], name='x')
y_true = tf.placeholder(tf.float32, shape=[None, num_classes], name='y_true')
y_true_cls = tf.argmax(y_true, dimension=1)

# %% [markdown]
# ### Neural Network
# Using **PrettyTensor** to describe it at a higher level.

# %%
# Wrap the transfer-values as a Pretty Tensor object.
x_pretty = pt.wrap(x)

with pt.defaults_scope(activation_fn=tf.nn.relu):
    y_pred, loss = x_pretty.\
        fully_connected(size=1024, name='layer_fc1').\
        softmax_classifier(class_count=num_classes, labels=y_true)

# %% [markdown]
# ### Optimization Method

# %%
# Keeps track of the number of optimization iterations performed.
global_step = tf.Variable(initial_value=0,
                          name='global_step', trainable=False)
# Adam Optimizer
optimizer = tf.train.AdamOptimizer(learning_rate=1e-4).minimize(loss, global_step)

# %% [markdown]
# ### Classification Accuracy

# %%
y_pred_cls = tf.argmax(y_pred, dimension=1)
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
# The classification accuracy is calculated by first type-casting the array of booleans to floats, 
# so that False becomes 0 and True becomes 1, and then taking the average of these numbers.
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %% [markdown]
# ### TensorFlow Run
# We create the $TensorFlow$ session and initialize the variables.

# %%
session = tf.Session()
session.run(tf.initialize_all_variables())

# %% [markdown]
# ### Helper-function to get a random training-batch
# As in all the previous notebooks, we need to use small batches for training, to avoid running out of memory.

# %%
train_batch_size = 64

def random_batch():
    ut.random_batch(transfer_values_train, train_batch_size, labels_train)

# %% [markdown]
# ### Helper-function to perform optimization

# %%
def optimize(num_iterations):
    ut.optimize(num_iterations, transfer_values_train, train_batch_size, 
                labels_train, session, global_step, optimizer, accuracy, x, y_true)

# %% [markdown]
# ### Helper-function to plot example errors
# This function plots examples of images from the test-set that have been mis-classified.

# %%
def plot_example_errors(cls_pred, correct):
    ut.plot_example_errors(cls_pred, correct, images_test, cls_test, plot_images, images)

# %% [markdown]
# ### Helper-function to plot confusion matrix

# %%
def plot_confusion_matrix(cls_pred):
    ut.plot_confusion_matrix(cls_pred, cls_test, num_classes, class_names)

# %% [markdown]
# ### Helper-functions for calculating classifications
# This function calculates the predicted classes of images and also returns a boolean array whether the classification of each image is correct.

# %%
# Split the data-set in batches of this size to limit RAM usage.
batch_size = 256

def predict_cls(transfer_values, labels, cls_true):
    # Number of images.
    num_images = len(transfer_values)
    # Allocate an array for the predicted classes which
    # will be calculated in batches and filled into this array.
    cls_pred = np.zeros(shape=num_images, dtype=np.int)
    # Now calculate the predicted classes for the batches.
    i = 0
    while i < num_images:
        # The ending index for the next batch is denoted j.
        j = min(i + batch_size, num_images)
        # Create a feed-dict with the images and labels
        # between index i and j.
        feed_dict = {x: transfer_values[i:j],
                     y_true: labels[i:j]}
        # Calculate the predicted class using TensorFlow.
        cls_pred[i:j] = session.run(y_pred_cls, feed_dict=feed_dict)
        # Set the start-index for the next batch to the end-index of the current batch.
        i = j
    # Create a boolean array whether each image is correctly classified.
    correct = (cls_true == cls_pred)
    return correct, cls_pred

# %% [markdown]
# ### Helper-functions for the classification accuracy
# This function calculates the classification accuracy given a boolean array whether each image was correctly classified.
#
# E.g. classification_accuracy([True, True, False, False, False]) = 2/5 = 0.4. The function also returns the number of correct classifications.

# %%
def classification_accuracy(correct):
    ut.classification_accuracy(correct)

# %% [markdown]
# ### Helper-function for showing the performance
# This function prints the classification accuracy on the test-set.

# %%
def print_test_accuracy(show_example_errors=False, show_confusion_matrix=False):
    ut.print_test_accuracy(show_example_errors, show_confusion_matrix, transfer_values_test, 
                           labels_test, cls_test, batch_size, images_test, plot_images, images, 
                           num_classes, class_names, predict_cls)

# %% [markdown]
# ## Results
# We'll now see the results before and after the optimizations.
#
# ### Performance before optimization

# %%
print_test_accuracy(show_example_errors=False, show_confusion_matrix=True)
# Out:
# Accuracy on Test-Set: 24.7% (109 / 442)
# Confusion Matrix:
# [  1  50 104] (0) duck
# [ 28  18 115] (1) drive
# [ 6 30 90] (2) apple
#  (0) (1) (2)

# %% [markdown]
# ### Performance after 1000 optimization iterations
# There is no need to save checkpoints this time, because 1000 iterations do not take so long to compute compared to the 100000 of notebook 03. Also we're now training only one fully connected layer instead of two fully connected layers and two convolutional layers. That's the main advantage of using transfer learning.

# %%
optimize(num_iterations=1000)
# Out:
# Global Step:    100, Training Batch Accuracy: 100.0%
# Global Step:    200, Training Batch Accuracy: 100.0%
# Global Step:    300, Training Batch Accuracy: 100.0%
# Global Step:    400, Training Batch Accuracy: 100.0%
# Global Step:    500, Training Batch Accuracy: 100.0%
# Global Step:    600, Training Batch Accuracy: 100.0%
# Global Step:    700, Training Batch Accuracy: 100.0%
# Global Step:    800, Training Batch Accuracy: 100.0%
# Global Step:    900, Training Batch Accuracy: 100.0%
# Global Step:   1000, Training Batch Accuracy: 100.0%
# Time usage: 0:00:33

# %% [markdown]
# As we can see, the optimizer takes a very little time to reach 100% accuracy on the training set (about 30 seconds on this virtual machine). More iterations would probably result in overfitting.

# %%
print_test_accuracy(show_example_errors=True, show_confusion_matrix=True)
# Out:
# Accuracy on Test-Set: 95.2% (421 / 442)
# Example errors:
# Confusion Matrix:
# [134  20   1] (0) duck
# [  0 161   0] (1) drive
# [  0   0 126] (2) apple
#  (0) (1) (2)

# %% [markdown]
# As we can see, the NN has a very high accuracy (about 95%) with less than a minute of training, which is remarkable. The errors are concentrated on the classification of rubber ducks and drives, just as we expected, because of the very low number of examples of drives and the absence of rubber ducks in ImageNet.

# %% [markdown]
# ## Classification of external images
# We also need to check if those results apply to pictures of different objects of the same category, so if the NN doesn't overfit our specific objects, but is also able to correctly classify different objects of the same classes.
#
# To do that we used a picture of a giant rubber duck baloon in a river, surrounded by buildings, an hard drive of a different brand and with the magnetic disk exposed, and finally a fuji apple (we used a granny smith and a red delicious for training and tests).

# %%
file_path_cache_manual = os.path.join(cache_dir, 'inception_05_manual.pkl')
image_paths_manual = ['imagesForClassification/duck.jpg',
                      'imagesForClassification/drive.jpg',
                      'imagesForClassification/apple.jpg']
cls_manual = [0, 1, 2]
labels_manual = [[ 1.,  0.,  0.], [ 0.,  1.,  0.], [ 0.,  0.,  1.]]
transfer_values_manual = transfer_values_cache(cache_path=file_path_cache_manual,
                                               image_paths=image_paths_manual,
                                               model=model)
images = load_images(image_paths=image_paths_manual)
u.plot_transfer_values(i=0, images=images, transfer_values=transfer_values_manual)
u.plot_transfer_values(i=1, images=images, transfer_values=transfer_values_manual)
u.plot_transfer_values(i=2, images=images, transfer_values=transfer_values_manual)

_,cls_pred_manual = predict_cls(transfer_values_manual, labels_manual, cls_manual)
# Out:
# - Data loaded from cache-file: cache/inception_05_manual.pkl
# Input image:
# Transfer-values for the image using Inception model:
# Input image:
# Transfer-values for the image using Inception model:
# Input image:
# Transfer-values for the image using Inception model:

# %%
cls_pred_manual
# Out:
# array([0, 1, 2])

# %%
predicted_classes = [class_names[cls_pred_manual[0]], class_names[cls_pred_manual[1]], class_names[cls_pred_manual[2]]]
predicted_classes
# Out:
# ['duck', 'drive', 'apple']

# %% [markdown]
# The network correctly classifies the 3 images as a duck, drive and apple.

# %% [markdown]
# ## Close TensorFlow Session

# %%
model.close()
session.close()

# %% [markdown]
# ## Performance
# The computation of the Transfer Values took much less this time, about 10 minutes. This is because the data set is smaller compared to CIFAR-10.
#
# We have a lower order of magnitude in the number of optimizations because of the lower number of classes, and this made the training even faster, taking less than a minute (about 30 seconds usually).
#
# The accuracy reached is around 95%.
#
# ## Conclusion
# Transfer Learning works incredibly well on sampled video data, even with very few examples, reaching accuracy close to 100% in seconds.
#
# The few errors produced are due to the lack of items in the original dataset (ImageNet) used to train Inception Model. As we can see, the classification does a perfect job recognizing apples, one of the biggest classes in ImageNet, while struggles a bit with rubber ducks, that has zero examples in ImageNet, mispredicting them with hard drives (despite apples looking way more similar in color and shape), another very poor class in ImageNet.
#
# In the next notebook we'll explore some serious problems with CNNs, and test a possible solution.
